# %%
import requests
import pandas as pd
import json
import pymysql 
import sqlalchemy

# %%
chicago_response = requests.get(f"https://data.cityofchicago.org/resource/3uz7-d32j.json").json()

# %%
chicago_response
# Out:
# [{':@computed_region_43wa_7qmu': '35',
#   ':@computed_region_6mkv_f3dw': '21546',
#   ':@computed_region_awaf_s7ux': '9',
#   ':@computed_region_bdys_3d7i': '491',
#   ':@computed_region_vrxf_vc4k': '44',
#   '_iucr': '0486',
#   '_location_description': 'RESIDENCE',
#   '_primary_decsription': 'BATTERY',
#   '_secondary_description': 'DOMESTIC BATTERY SIMPLE',
#   'arrest': 'N',
#   'beat': '413',
#   'block': '092XX S BLACKSTONE AVE',
#   'case_': 'JB151380',
#   'date_of_occurrence': '2018-02-14T05:18:00.000',
#   'domestic': 'N',
#   'fbi_cd': '08B',
#   'latitude': '41.727125922',
#   'location': {'type': 'Point', 'coordinates': [-87.587915691, 41.727125922]},
#   'longitude': '-87.587915691',
#   'ward': '8',
#   'x_coordinate': '1187728',
#   'y_coordinate': '1844037'},
#  {':@computed_region_43wa_7qmu': '46',
#   ':@computed_region_6mkv_f3dw': '22620',
#   ':@computed_region_awaf_s7ux': '41',
#   ':@computed_region_bdys_3d7i': '484',
#   ':@computed_region_vrxf_vc4k': '25',
# ...

# %%
df = pd.DataFrame(chicago_response)

# %%
df.head()
# Out:
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                          35                       21546
# 1                          46                       22620
# 2                          11                       14926
# 3                           2                       22257
# 4                           4                       22260
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                           9                         491
# 1                          41                         484
# 2                          22                         230
# 3                          19                         384
# 4                          53                         401
#
#   :@computed_region_vrxf_vc4k _iucr _location_description  \
# 0                          44  0486             RESIDENCE
# 1                          25  031A              SIDEWALK
# 2                          37  0460              SIDEWALK
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+mysqldb://root:mysql#2019@127.0.0.1/chicago_staging")
df.to_sql(con=engine, name='crime_ward', if_exists='append', index=False)
