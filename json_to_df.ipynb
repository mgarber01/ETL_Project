# %%
import requests
import pandas as pd
import json

# %%
chicago_response = requests.get(f"https://data.cityofchicago.org/resource/dkvj-fe84.json").json()

# %%
chicago_response
# Out:
# [{'dates': '2,3',
#   'month_name': 'OCTOBER',
#   'month_number': '10',
#   'section': '14',
#   'ward': '8',
#   'ward_section_concatenated': '0814'},
#  {'dates': '22,25',
#   'month_name': 'JUNE',
#   'month_number': '6',
#   'section': '9',
#   'ward': '9',
#   'ward_section_concatenated': '0909'},
#  {'dates': '14,15',
#   'month_name': 'AUGUST',
#   'month_number': '8',
#   'section': '6',
#   'ward': '2',
#   'ward_section_concatenated': '0206'},
#  {'dates': '16,17',
#   'month_name': 'AUGUST',
#   'month_number': '8',
#   'section': '3',
#   'ward': '4',
#   'ward_section_concatenated': '0403'},
#  {'dates': '30',
#   'month_name': 'APRIL',
#   'month_number': '4',
#   'section': '11',
#   'ward': '1',
#   'ward_section_concatenated': '0111'},
#  {'dates': '10,11',
#   'month_name': 'APRIL',
#   'month_number': '4',
#   'section': '4',
#   'ward': '4',
#   'ward_section_concatenated': '0404'},
#  {'dates': '11,12',
#   'month_name': 'SEPTEMBER',
#   'month_number': '9',
# ...

# %%
df = pd.DataFrame(chicago_response)

# %%
df.head()
# Out:
#    dates month_name month_number section ward ward_section_concatenated
# 0    2,3    OCTOBER           10      14    8                      0814
# 1  22,25       JUNE            6       9    9                      0909
# 2  14,15     AUGUST            8       6    2                      0206
# 3  16,17     AUGUST            8       3    4                      0403
# 4     30      APRIL            4      11    1                      0111
